# %%
data <- read.csv('VA_accidents_final.csv')

# %%
t.test(data$Severity[data$Side=='L'],data$Severity[data$Side=='R'], alternative='less')
# Out:
# 	Welch Two Sample t-test
#
# data:  data$Severity[data$Side == "L"] and data$Severity[data$Side == "R"]
# t = -42.574, df = 11918, p-value < 2.2e-16
# alternative hypothesis: true difference in means is less than 0
# 95 percent confidence interval:
#       -Inf -0.299763
# sample estimates:
# mean of x mean of y
#  2.278117  2.589928

# %%
t.test(data$Severity[data$accidentPlaceOccurrence<1],data$Severity[data$accidentPlaceOccurrence>1], alternative='less')
# Out:
# 	Welch Two Sample t-test
#
# data:  data$Severity[data$accidentPlaceOccurrence < 1] and data$Severity[data$accidentPlaceOccurrence > 1]
# t = 48.226, df = 2203.6, p-value = 1
# alternative hypothesis: true difference in means is less than 0
# 95 percent confidence interval:
#       -Inf 0.4938087
# sample estimates:
# mean of x mean of y
#  2.595067  2.117551

# %%
library(GGally)
# Out:
# Loading required package: ggplot2
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
ggcorr(data, palette = "RdBu", label = TRUE)
# Out:
# Warning message in ggcorr(data, palette = "RdBu", label = TRUE):
# "data in column(s) 'Source', 'Start_Time', 'End_Time', 'Description', 'Street', 'Side', 'City', 'County', 'Timezone', 'Airport_Code', 'Weather_Timestamp', 'Wind_Direction', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight' are not numeric and were ignored"
# plot without title
